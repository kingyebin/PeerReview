# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
pwd
# Out:
# '/Users/adam_ham/dl/aiffel_Orderlee/pokemon_eda_240219'

# %%
#csv_path = os.getenv('HOME') + '/aiffel/aiffel_quest/pokemon_eda_240219/data/Pokemon.csv'
csv_path = './data/Pokemon.csv'
# print(csv_path)
original_data = pd.read_csv(csv_path)
original_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon = original_data.copy()
print(pokemon.shape)
pokemon.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
legendary = pokemon[pokemon['Legendary'] == True].reset_index(drop=True)
print(legendary.shape)
legendary.head()
# Out:
# (65, 13)
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       95      125     85           1       True
# 1      125       90    100           1       True
# 2      125       85     90           1       True
# 3      154       90    130           1       True
# 4      154      100    130           1       True

# %%
ordinary = pokemon[pokemon['Legendary'] == False].reset_index(drop=True)
print(ordinary.shape)
ordinary.head()
# Out:
# (735, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon.isnull().mean()
# Out:
# #             0.0000
# Name          0.0000
# Type 1        0.0000
# Type 2        0.4825
# Total         0.0000
# HP            0.0000
# Attack        0.0000
# Defense       0.0000
# Sp. Atk       0.0000
# Sp. Def       0.0000
# Speed         0.0000
# Generation    0.0000
# Legendary     0.0000
# dtype: float64

# %%
print(len(pokemon.columns))
pokemon.columns
# Out:
# 13
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
len(set(pokemon['#']))
# Out:
# 721

# %%
pokemon[pokemon["#"] == 6]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
len(pokemon['Name'].unique())
# Out:
# 800

# %%
pokemon.loc[[6,10]]
# Out:
#     #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 6   6  Charizard   Fire  Flying    534  78      84       78      109       85
# 10  8  Wartortle  Water     NaN    405  59      63       80       65       80
#
#     Speed  Generation  Legendary
# 6     100           1      False
# 10     58           1      False

# %%
len(list(set(pokemon['Type 1']))), len(list(set(pokemon['Type 2'])))
# Out:
# (18, 19)

# %%
set(pokemon['Type 2']) - set(pokemon['Type 1'])
# Out:
# {nan}

# %%
types = list(set(pokemon['Type 1']))
print(len(types))
print(types)
# Out:
# 18
# ['Fighting', 'Steel', 'Dark', 'Poison', 'Fire', 'Bug', 'Fairy', 'Psychic', 'Water', 'Normal', 'Ice', 'Flying', 'Rock', 'Electric', 'Grass', 'Ground', 'Ghost', 'Dragon']

# %%
pokemon['Type 2'].isna().sum()
# Out:
# 386

# %%
plt.figure(figsize=(15,7))

plt.subplot(211)
sns.countplot(data=ordinary, x='Type 1', order=types).set_xlabel('')
plt.title('Ordinary Pokemons')

plt.subplot(212)
sns.countplot(data=legendary, x='Type 1', order=types).set_xlabel('')
plt.title('Legendary Pokemons')

plt.show()

# %%
pd.pivot_table(pokemon, index='Type 1', values='Legendary').sort_values(by=['Legendary'], ascending=False)
# Out:
#           Legendary
# Type 1
# Flying     0.500000
# Dragon     0.375000
# Psychic    0.245614
# Steel      0.148148
# Ground     0.125000
# Fire       0.096154
# Electric   0.090909
# Rock       0.090909
# Ice        0.083333
# Dark       0.064516
# Ghost      0.062500
# Fairy      0.058824
# Grass      0.042857
# Water      0.035714
# Normal     0.020408
# Poison     0.000000
# Fighting   0.000000
# Bug        0.000000

# %%
plt.figure(figsize=(15,7))

plt.subplot(211)
sns.countplot(data=ordinary, x='Type 2', order=types).set_xlabel('')
plt.title('Ordinary Pokemons')

plt.subplot(212)
sns.countplot(data=legendary, x='Type 2', order=types).set_xlabel('')
plt.title('Legendary Pokemons')

plt.show()

# %%
pd.pivot_table(pokemon, index='Type 2', values='Legendary').sort_values(by=['Legendary'], ascending=False)
# Out:
#           Legendary
# Type 2
# Fire       0.250000
# Dragon     0.222222
# Ice        0.214286
# Electric   0.166667
# Fighting   0.153846
# Psychic    0.151515
# Flying     0.134021
# Fairy      0.086957
# Water      0.071429
# Ghost      0.071429
# Dark       0.050000
# Steel      0.045455
# Ground     0.028571
# Rock       0.000000
# Bug        0.000000
# Poison     0.000000
# Normal     0.000000
# Grass      0.000000

# %%
stats = ['HP', 'Attack', 'Defense', "Sp. Atk", "Sp. Def", 'Speed']
stats
# Out:
# ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
print('#0 pokemon: ', pokemon.loc[0, 'Name'])
print('total: ', int(pokemon.loc[0, 'Total']))
print('stats: ', list(pokemon.loc[0, stats]))
print('sum of all stats: ', sum(list(pokemon.loc[0, stats])))
# Out:
# #0 pokemon:  Bulbasaur
# total:  318
# stats:  [45, 49, 49, 65, 65, 45]
# sum of all stats:  318

# %%
pokemon['Total'].values[:4]
# Out:
# array([318, 405, 525, 625])

# %%
pokemon[stats].values[:5]
# Out:
# array([[ 45,  49,  49,  65,  65,  45],
#        [ 60,  62,  63,  80,  80,  60],
#        [ 80,  82,  83, 100, 100,  80],
#        [ 80, 100, 123, 122, 120,  80],
#        [ 39,  52,  43,  60,  50,  65]])

# %%
pokemon[stats].values[:5].sum(axis=1)
# Out:
# array([318, 405, 525, 625, 309])

# %%
fig , ax = plt.subplots()
fig.set_size_inches(20,6)

sns.scatterplot(data=pokemon, x='Type 1', y='Total', hue='Legendary')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(211)
sns.countplot(data=ordinary, x='Generation').set_xlabel('')
plt.title('Ordinary Pokemons')

plt.subplot(212)
sns.countplot(data=legendary, x='Generation').set_xlabel('')
plt.title('Legendary Pokemons')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,4)

sns.scatterplot(data=legendary, y='Type 1', x='Total')
plt.show()

# %%
print(sorted(list(set(legendary['Total']))))
# Out:
# [580, 600, 660, 670, 680, 700, 720, 770, 780]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.countplot(data=legendary, x='Total')
plt.show()

# %%
round(65 / 9, 2)
# Out:
# 7.22

# %%
print(sorted(list(set(ordinary["Total"]))))
# Out:
# [180, 190, 194, 195, 198, 200, 205, 210, 213, 215, 218, 220, 224, 236, 237, 240, 244, 245, 250, 251, 253, 255, 260, 262, 263, 264, 265, 266, 269, 270, 273, 275, 278, 280, 281, 285, 288, 289, 290, 292, 294, 295, 299, 300, 302, 303, 304, 305, 306, 307, 308, 309, 310, 313, 314, 315, 316, 318, 319, 320, 323, 325, 328, 329, 330, 334, 335, 336, 340, 341, 345, 348, 349, 350, 351, 352, 355, 358, 360, 362, 363, 365, 369, 370, 371, 375, 380, 382, 384, 385, 390, 395, 400, 401, 405, 409, 410, 411, 413, 414, 415, 418, 420, 423, 424, 425, 428, 430, 431, 435, 438, 440, 442, 445, 446, 448, 450, 452, 454, 455, 456, 458, 460, 461, 462, 464, 465, 466, 467, 468, 470, 471, 472, 473, 474, 475, 479, 480, 481, 482, 483, 484, 485, 487, 488, 489, 490, 494, 495, 497, 498, 499, 500, 505, 507, 508, 509, 510, 514, 515, 518, 519, 520, 521, 523, 525, 528, 530, 531, 534, 535, 540, 545, 550, 552, 555, 560, 565, 567, 575, 579, 580, 590, 594, 600, 610, 615, 618, 625, 630, 634, 635, 640, 670, 700]

# %%
print(len(sorted(list(set(ordinary["Total"])))))
# Out:
# 195

# %%
round(735 / 195, 2)
# Out:
# 3.77

# %%
n1, n2, n3, n4, n5 = legendary[3:6], legendary[14:24], legendary[25:29], legendary[46:50], legendary[52:57]
names = pd.concat([n1,n2,n3,n4,n5]).reset_index(drop=True)
names
# Out:
#       #                      Name    Type 1    Type 2  Total   HP  Attack  \
# 0   150                    Mewtwo   Psychic       NaN    680  106     110
# 1   150       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 2   150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 3   380                    Latias    Dragon   Psychic    600   80      80
# 4   380         LatiasMega Latias    Dragon   Psychic    700   80     100
# 5   381                    Latios    Dragon   Psychic    600   80      90
# 6   381         LatiosMega Latios    Dragon   Psychic    700   80     130
# 7   382                    Kyogre     Water       NaN    670  100     100
# 8   382       KyogrePrimal Kyogre     Water       NaN    770  100     150
# 9   383                   Groudon    Ground       NaN    670  100     150
# 10  383     GroudonPrimal Groudon    Ground      Fire    770  100     180
# 11  384                  Rayquaza    Dragon    Flying    680  105     150
# ...

# %%
forme = names[13:23]
forme
# Out:
#       #                      Name    Type 1  Type 2  Total  HP  Attack  \
# 13  386        DeoxysNormal Forme   Psychic     NaN    600  50     150
# 14  386        DeoxysAttack Forme   Psychic     NaN    600  50     180
# 15  386       DeoxysDefense Forme   Psychic     NaN    600  50      70
# 16  386         DeoxysSpeed Forme   Psychic     NaN    600  50      95
# 17  641   TornadusIncarnate Forme    Flying     NaN    580  79     115
# 18  641     TornadusTherian Forme    Flying     NaN    580  79     100
# 19  642  ThundurusIncarnate Forme  Electric  Flying    580  79     115
# 20  642    ThundurusTherian Forme  Electric  Flying    580  79     105
# 21  645   LandorusIncarnate Forme    Ground  Flying    600  89     125
# 22  645     LandorusTherian Forme    Ground  Flying    600  89     145
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 13       50      150       50    150           3       True
# 14       20      180       20    150           3       True
# ...

# %%
legendary['name_count'] = legendary['Name'].apply(lambda i: len(i))
legendary.head()
# Out:
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       95      125     85           1       True           8
# 1      125       90    100           1       True           6
# 2      125       85     90           1       True           7
# 3      154       90    130           1       True           6
# 4      154      100    130           1       True          19

# %%
ordinary['name_count'] = ordinary['Name'].apply(lambda i : len(i))
ordinary.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
plt.figure(figsize=(15,10))

plt.subplot(211)
sns.countplot(data=legendary, x='name_count').set_xlabel('')
plt.title('legendary')

plt.subplot(212)
sns.countplot(data=ordinary, x='name_count').set_xlabel('')
plt.title('ordinary')

plt.show()

# %%
print(round(len(legendary[legendary['name_count'] > 9]) / len(legendary) * 100, 2), '%')
# Out:
# 41.54 %

# %%
print(round(len(ordinary[ordinary['name_count'] > 9]) / len(ordinary) * 100, 2), '%')
# Out:
# 15.65 %

# %%
pokemon['name_count'] = pokemon['Name'].apply(lambda i: len(i))
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
pokemon['long_name'] = pokemon['name_count'] >= 10
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True

# %%
pokemon['Name_nospace'] = pokemon['Name'].apply(lambda i : i.replace(' ',''))
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 795      100      150     50           6       True           7      False
# 796      160      110    110           6       True          19       True
# 797      150      130     70           6       True          19       True
# 798      170      130     80           6       True          18       True
# 799      130       90     70           6       True           9      False
#
#            Name_nospace
# 795             Diancie
# ...

# %%
pokemon['name_isalpha'] = pokemon['Name_nospace'].apply(lambda i : i.isalpha())
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True
#
#            Name_nospace  name_isalpha
# 0             Bulbasaur          True
# ...

# %%
print(pokemon[pokemon['name_isalpha'] == False].shape)
pokemon[pokemon['name_isalpha'] == False]
# Out:
# (9, 17)
#        #              Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29          Nidoran♀   Poison     NaN    275   55      47       52
# 37    32          Nidoran♂   Poison     NaN    273   46      57       40
# 90    83        Farfetch'd   Normal  Flying    352   52      65       55
# 131  122          Mr. Mime  Psychic   Fairy    460   40      45       65
# 252  233          Porygon2   Normal     NaN    515   85      80       90
# 270  250             Ho-oh     Fire  Flying    680  106     130       90
# 487  439          Mime Jr.  Psychic   Fairy    310   20      25       45
# 525  474         Porygon-Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon Two")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

pokemon.loc[[34, 37, 90, 131, 252, 270, 487, 525, 794]]
# Out:
#        #           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29      Nidoran X   Poison     NaN    275   55      47       52
# 37    32      Nidoran Y   Poison     NaN    273   46      57       40
# 90    83      Farfetchd   Normal  Flying    352   52      65       55
# 131  122        Mr Mime  Psychic   Fairy    460   40      45       65
# 252  233    Porygon Two   Normal     NaN    515   85      80       90
# 270  250          Ho Oh     Fire  Flying    680  106     130       90
# 487  439        Mime Jr  Psychic   Fairy    310   20      25       45
# 525  474      Porygon Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
pokemon['Name_nospace'] = pokemon['Name'].apply(lambda i : i.replace(' ',''))
pokemon['name_isalpha'] = pokemon['Name_nospace'].apply(lambda i: i.isalpha())

print(pokemon[pokemon['name_isalpha'] == False].shape)
pokemon[pokemon['name_isalpha'] == False]
# Out:
# (0, 17)
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %% [markdown]
# ## 정규 표현식
# - [A-Z] : A부터 Z까지의 대문자 중 한 가지로 시작하고,
# - [a-z] : 그 뒤에 a부터 z까지의 소문자 중 한 가지가 붙는데,
# - ___*___ : 그 소문자의 개수는 하나 이상인 패턴 (*는 정규표현식 중에서 "반복"을 나타내는 기호)

# %%
import re

name = "CharizardMega Charizard X"

# %%
name_split = name.split(" ")
name_split
# Out:
# ['CharizardMega', 'Charizard', 'X']

# %%
temp = name_split[0]
temp
# Out:
# 'CharizardMega'

# %%
tokens = re.findall('[A-Z][a-z]*', temp)
tokens
# Out:
# ['Charizard', 'Mega']

# %%
tokens = []
for part_name in name_split:
    a = re.findall('[A-Z][a-z]*', part_name)
    tokens.extend(a)
tokens
# Out:
# ['Charizard', 'Mega', 'Charizard', 'X']

# %%
def tokenize(name):
    tokens = re.findall('[A-Z][a-z]*', name)
    return np.array(tokens)

# %%
name = "CharizardMega Charizard X"
tokenize(name)
# Out:
# array(['Charizard', 'Mega', 'Charizard', 'X'], dtype='<U9')

# %%
all_tokens = list(legendary['Name'].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)
    
print(len(set(token_set)))
print(token_set)
# Out:
# 65
# ...

# %%
from collections import Counter

a = [1,1,0,0,0,1,1,2,3]
Counter(a)
# Out:
# Counter({1: 4, 0: 3, 2: 1, 3: 1})

# %%
Counter(a).most_common()
# Out:
# [(1, 4), (0, 3), (2, 1), (3, 1)]

# %%
most_common = Counter(token_set).most_common(10)
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
for token, _ in most_common:
    pokemon[f"{token}"] = pokemon['Name'].str.contains(token)
    
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  ...  Forme   Mega  Mewtwo  Kyurem  Deoxys  Hoopa  Latias  \
# ...

# %%
print(types)
# Out:
# ['Fighting', 'Steel', 'Dark', 'Poison', 'Fire', 'Bug', 'Fairy', 'Psychic', 'Water', 'Normal', 'Ice', 'Flying', 'Rock', 'Electric', 'Grass', 'Ground', 'Ghost', 'Dragon']

# %%
for t in types:
    pokemon[t] = (pokemon['Type 1'] == t) | (pokemon['Type 2'] == t)
    
pokemon[[['Type 1', 'Type 2'] + types][0]].head()
# Out:
#   Type 1  Type 2  Fighting  Steel   Dark  Poison   Fire    Bug  Fairy  \
# 0  Grass  Poison     False  False  False    True  False  False  False
# 1  Grass  Poison     False  False  False    True  False  False  False
# 2  Grass  Poison     False  False  False    True  False  False  False
# 3  Grass  Poison     False  False  False    True  False  False  False
# 4   Fire     NaN     False  False  False   False   True  False  False
#
#    Psychic  Water  Normal    Ice  Flying   Rock  Electric  Grass  Ground  \
# 0    False  False   False  False   False  False     False   True   False
# 1    False  False   False  False   False  False     False   True   False
# 2    False  False   False  False   False  False     False   True   False
# 3    False  False   False  False   False  False     False   True   False
# 4    False  False   False  False   False  False     False  False   False
#
#    Ghost  Dragon
# 0  False   False
# 1  False   False
# 2  False   False
# 3  False   False
# ...

# %%
print(original_data.shape)
original_data.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
original_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']

# %%
target=['Legendary']

# %%
X = original_data[features]
print(X.shape)
X.head()
# Out:
# (800, 8)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1

# %%
y = original_data[target]
print(y.shape)
y.head()
# Out:
# (800, 1)
#    Legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=205)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (640, 8) (160, 8)
# (640, 1) (160, 1)

# %% [markdown]
# ## 의사 결정 나무

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.98125

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[144,   1],
#        [  2,  13]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       145
#         True       0.93      0.87      0.90        15
#
#     accuracy                           0.98       160
#    macro avg       0.96      0.93      0.94       160
# weighted avg       0.98      0.98      0.98       160

# %% [markdown]
# ## 피쳐 엔지니어링

# %%
print(len(pokemon.columns))
print(pokemon.columns)
# Out:
# 45
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'name_count',
#        'long_name', 'Name_nospace', 'name_isalpha', 'Forme', 'Mega', 'Mewtwo',
#        'Kyurem', 'Deoxys', 'Hoopa', 'Latias', 'Latios', 'Kyogre', 'Groudon',
#        'Fighting', 'Steel', 'Dark', 'Poison', 'Fire', 'Bug', 'Fairy',
#        'Psychic', 'Water', 'Normal', 'Ice', 'Flying', 'Rock', 'Electric',
#        'Grass', 'Ground', 'Ghost', 'Dragon'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Generation','name_count',
       'long_name', 'Forme', 'Mega', 'Mewtwo',
       'Kyurem', 'Deoxys', 'Hoopa', 'Latias', 'Latios', 'Kyogre', 'Groudon',
       'Fighting', 'Rock', 'Water', 'Electric', 'Ground', 'Normal', 'Ice',
       'Ghost', 'Fire', 'Dragon', 'Fairy', 'Psychic', 'Dark', 'Poison',
       'Steel', 'Flying', 'Bug', 'Grass']

len(features)
# Out:
# 38

# %%
target = ['Legendary']

# %%
X = pokemon[features]
print(X.shape)
X.head()
# Out:
# (800, 38)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1
#
#    name_count  long_name  ...   Fire  Dragon  Fairy  Psychic   Dark  Poison  \
# 0           9      False  ...  False   False  False    False  False    True
# 1           7      False  ...  False   False  False    False  False    True
# 2           8      False  ...  False   False  False    False  False    True
# 3          21       True  ...  False   False  False    False  False    True
# 4          10       True  ...   True   False  False    False  False   False
#
#    Steel  Flying    Bug  Grass
# 0  False   False  False   True
# ...

# %%
y = pokemon[target]
print(y.shape)
y.head()
# Out:
# (800, 1)
#    Legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=205)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (640, 38) (160, 38)
# (640, 1) (160, 1)

# %%
model = DecisionTreeClassifier(random_state=205)
model
# Out:
# DecisionTreeClassifier(random_state=205)

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.96875

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[143   3]
#  [  2  12]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.98       146
#         True       0.80      0.86      0.83        14
#
#     accuracy                           0.97       160
#    macro avg       0.89      0.92      0.91       160
# weighted avg       0.97      0.97      0.97       160

# %% [markdown]
# ## 의사결정 나무 하이퍼파라미터

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'min_samples_split':[2,4,6,8],
          'min_samples_leaf':[2,4,6,8],
         'max_depth':[3,5,7,9],
         }

# %%
# xgb = DecisionTreeClassifier()
grid = RandomizedSearchCV(model, params, cv=5, n_iter=10, n_jobs=-1)
grid.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=205),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [3, 5, 7, 9],
#                                         'min_samples_leaf': [2, 4, 6, 8],
#                                         'min_samples_split': [2, 4, 6, 8]})

# %%
grid.best_params_
# Out:
# {'min_samples_split': 2, 'min_samples_leaf': 8, 'max_depth': 3}

# %%
model = DecisionTreeClassifier(
    min_samples_split=8,
    min_samples_leaf=8,
    max_depth=3,
    random_state=205)
model
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=8, min_samples_split=8,
#                        random_state=205)

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.96875

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[140   0]
#  [  5  15]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98       140
#         True       1.00      0.75      0.86        20
#
#     accuracy                           0.97       160
#    macro avg       0.98      0.88      0.92       160
# weighted avg       0.97      0.97      0.97       160

# %% [markdown]
# ## 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=205)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# /Users/adam_ham/anaconda3/envs/aiffel/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.9875

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[145   2]
#  [  0  13]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99       147
#         True       0.87      1.00      0.93        13
#
#     accuracy                           0.99       160
#    macro avg       0.93      0.99      0.96       160
# weighted avg       0.99      0.99      0.99       160

# %% [markdown]
# ## 랜덤 포레스트 하이퍼파라미터

# %%
params = {'n_estimators':[100,200,300,400],
          'min_samples_leaf':[2,4,6,8],
         'max_depth':[3,5,7,9],
          'min_samples_split':[2,4,6,8]
         }

# %%
grid = RandomizedSearchCV(model, params, cv=5, n_iter=10, n_jobs=-1)
grid.fit(X,y)
# Out:
# /Users/adam_ham/anaconda3/envs/aiffel/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/adam_ham/anaconda3/envs/aiffel/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/adam_ham/anaconda3/envs/aiffel/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
grid.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_depth': 7}

# %%
model = RandomForestClassifier(
                               n_estimators=300,
                               min_samples_split=6,
                               min_samples_leaf=4,
                               max_depth=7,
                               random_state=205)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# /Users/adam_ham/anaconda3/envs/aiffel/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.96875

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[143   3]
#  [  2  12]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.98       146
#         True       0.80      0.86      0.83        14
#
#     accuracy                           0.97       160
#    macro avg       0.89      0.92      0.91       160
# weighted avg       0.97      0.97      0.97       160

# %% [markdown]
# 하이퍼파라미터를 수정하자 오히려 더 떨어지는 걸 확인했다.

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
model = XGBClassifier(random_state=205, use_label_encoder=False, eval_metric='logloss')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.98125

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[143   1]
#  [  2  14]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       144
#            1       0.93      0.88      0.90        16
#
#     accuracy                           0.98       160
#    macro avg       0.96      0.93      0.95       160
# weighted avg       0.98      0.98      0.98       160

# %% [markdown]
# ## XGBoost 하이퍼파라미터

# %%
params = {'booster': ['gbtree', 'gblinear', 'dart'],
          'n_estimators':[100,200,300,400],
         'max_depth':[8,10,12,14],
          'learning_rate':[0.2, 0.3 ,0.4, 0.5]
         }

# %%
# grid = RandomizedSearchCV(model, params, cv=5, n_iter=10, n_jobs=-1)
# grid.fit(X,y)

# %%
# grid.best_params_

# %%
model = XGBClassifier(
    random_state=205, 
    booster='gbtree',
    n_jobs=-1,
    max_depth=14,
    n_estimators=100,
    learning_rate=0.2,
    use_label_encoder=False, 
    eval_metric='logloss',)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9875

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[143   0]
#  [  2  15]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       143
#            1       1.00      0.88      0.94        17
#
#     accuracy                           0.99       160
#    macro avg       0.99      0.94      0.97       160
# weighted avg       0.99      0.99      0.99       160

# %% [markdown]
# 랜덤포레스트에서 recall 값이 1이 나오는것을 확인했지만
# 숫자값들을 스케일링을 하면 어떠한 결과가 나올지 궁금했다.
# 스케일을 진행 한 후 학습을 진행을 했다.

# %% [markdown]
# ### 스케일

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
# X.columns
# X 

X_int = X.iloc[:,:9]
# X_int
X_obj = X.iloc[:,10:]
# X_obj

# %%
X_int = mm.fit_transform(X_int)
# X_int
X_int = pd.DataFrame(X_int, columns=X.iloc[:,:9].columns)
X_int
# Out:
#         Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# 0    0.230000  0.173228  0.237838  0.195556  0.298913  0.214286  0.228571
# 1    0.375000  0.232283  0.308108  0.257778  0.380435  0.285714  0.314286
# 2    0.575000  0.311024  0.416216  0.346667  0.489130  0.380952  0.428571
# 3    0.741667  0.311024  0.513514  0.524444  0.608696  0.476190  0.428571
# 4    0.215000  0.149606  0.254054  0.168889  0.271739  0.142857  0.342857
# ..        ...       ...       ...       ...       ...       ...       ...
# 795  0.700000  0.192913  0.513514  0.644444  0.489130  0.619048  0.257143
# 796  0.866667  0.192913  0.837838  0.466667  0.815217  0.428571  0.600000
# 797  0.700000  0.311024  0.567568  0.244444  0.760870  0.523810  0.371429
# 798  0.833333  0.311024  0.837838  0.244444  0.869565  0.523810  0.428571
# 799  0.700000  0.311024  0.567568  0.511111  0.652174  0.333333  0.371429
#
#      Generation  name_count
# 0           0.0    0.272727
# ...

# %%
X_scale = pd.concat([X_int,X_obj], axis=1)
X_scale
# Out:
#         Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# 0    0.230000  0.173228  0.237838  0.195556  0.298913  0.214286  0.228571
# 1    0.375000  0.232283  0.308108  0.257778  0.380435  0.285714  0.314286
# 2    0.575000  0.311024  0.416216  0.346667  0.489130  0.380952  0.428571
# 3    0.741667  0.311024  0.513514  0.524444  0.608696  0.476190  0.428571
# 4    0.215000  0.149606  0.254054  0.168889  0.271739  0.142857  0.342857
# ..        ...       ...       ...       ...       ...       ...       ...
# 795  0.700000  0.192913  0.513514  0.644444  0.489130  0.619048  0.257143
# 796  0.866667  0.192913  0.837838  0.466667  0.815217  0.428571  0.600000
# 797  0.700000  0.311024  0.567568  0.244444  0.760870  0.523810  0.371429
# 798  0.833333  0.311024  0.837838  0.244444  0.869565  0.523810  0.428571
# 799  0.700000  0.311024  0.567568  0.511111  0.652174  0.333333  0.371429
#
#      Generation  name_count  Forme  ...   Fire  Dragon  Fairy  Psychic   Dark  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.2, random_state=205)
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (640, 37) (160, 37)
# (640, 1) (160, 1)

# %%
model = DecisionTreeClassifier(random_state=205)
model
# Out:
# DecisionTreeClassifier(random_state=205)

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.98125

# %%
print(confusion_matrix(y_pred, y_test))
# Out:
# [[143   1]
#  [  2  14]]

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       144
#         True       0.93      0.88      0.90        16
#
#     accuracy                           0.98       160
#    macro avg       0.96      0.93      0.95       160
# weighted avg       0.98      0.98      0.98       160

# %% [markdown]
# 스케일을 하고 기본 학습을 진행했을 때 오히려 더 좋은 결과가 나오는 것을 확인
# 스케일 하고 학습을 하고 파라미터를 변경하면 더 좋은 효과를 확인 할 수 있을 것 같다

# %% [markdown]
# ## 상관관계 확인

# %%
numeric_columns = original_data.drop(['#','Name','Type 1','Type 2'],axis=1).columns

# %%
correlation_matrix = original_data[numeric_columns].corr()

plt.figure(figsize=(18,15))
sns.heatmap(correlation_matrix, annot=True, vmin=-1.0, vmax=1.0)
plt.show()

# %%
plt.figure(figsize=(20, 10))
for column in ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']:
    sns.kdeplot(original_data[column], shade=True)
plt.show()
# Out:
# /var/folders/1f/nd63my_54p70ccwh7d3cnt580000gn/T/ipykernel_67131/654695154.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(original_data[column], shade=True)
# /var/folders/1f/nd63my_54p70ccwh7d3cnt580000gn/T/ipykernel_67131/654695154.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(original_data[column], shade=True)
# /var/folders/1f/nd63my_54p70ccwh7d3cnt580000gn/T/ipykernel_67131/654695154.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(original_data[column], shade=True)
# /var/folders/1f/nd63my_54p70ccwh7d3cnt580000gn/T/ipykernel_67131/654695154.py:3: FutureWarning:
#
# ...

# %% [markdown]
# # 회고
#
# 노드에서 알려주시는 방식으로 진행을 하고 학습을 진행 했을 때 좀 많이 도움이 되었었고
# 다른 피쳐들을 삭제하고 진행을 하지 못해서 아쉬웠습니다.
